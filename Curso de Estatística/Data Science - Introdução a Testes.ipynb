# %%
import pandas as pd

tmdb = pd.read_csv("dados/tmdb_5000_movies.csv")
tmdb.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
import seaborn as sns

ax = sns.distplot(tmdb.vote_average)
ax.set(xlabel='Nota Média', ylabel = '')
ax.set_title("Média de votos em filmes no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/1656639168.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.vote_average)
# Text(0.5, 1.0, 'Média de votos em filmes no TMDB 5000')

# %%
import seaborn as sns

ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde = False)
ax.set(xlabel='Nota Média', ylabel = 'Frequência')
ax.set_title("Média de votos em filmes no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/242464776.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.vote_average, norm_hist = False, kde = False)
# Text(0.5, 1.0, 'Média de votos em filmes no TMDB 5000')

# %%
ax = sns.boxplot(x=tmdb.vote_average)
ax.set(xlabel='Nota média do filme')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000')
# Out:
# Text(0.5, 1.0, 'Distribuição de nota média dos filmes do TMDB 5000')

# %%
tmdb.query("vote_average == 0").head(5)
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# 3852                            NaN  395766
# 3855    http://www.timetochoose.com  370662
#
#                                                keywords original_language  \
# 1464                                                 []                en
# 3669                                                 []                en
# 3670                                                 []                en
# ...

# %%
tmdb.query('vote_average == 10').head(5)
# Out:
#       budget                                             genres homepage  \
# 3519       0                     [{"id": 35, "name": "Comedy"}]      NaN
# 4045       0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...      NaN
# 4247       1  [{"id": 10749, "name": "Romance"}, {"id": 35, ...      NaN
# 4662       0                     [{"id": 35, "name": "Comedy"}]      NaN
#
#           id                                           keywords  \
# 3519   89861  [{"id": 131, "name": "italy"}, {"id": 8250, "n...
# 4045   78373  [{"id": 1415, "name": "small town"}, {"id": 15...
# 4247  361505                                                 []
# 4662   40963        [{"id": 10183, "name": "independent film"}]
#
#      original_language         original_title  \
# 3519                en       Stiff Upper Lips
# 4045                en  Dancer, Texas Pop. 81
# 4247                en  Me You and Five Bucks
# 4662                en         Little Big Top
#
# ...

# %%
tmdb_com_mais_de_10_votos = tmdb.query("vote_count >= 10")
tmdb_com_mais_de_10_votos.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.392000e+03    4392.000000  4392.000000  4.392000e+03  4391.000000
# mean   3.164545e+07   49204.119991    23.448815  8.990969e+07   108.430881
# std    4.162736e+07   80136.249777    32.592158  1.682870e+08    21.014719
# min    0.000000e+00       5.000000     0.011697  0.000000e+00     0.000000
# 25%    2.895962e+06    8403.500000     6.512166  1.365700e+04    95.000000
# 50%    1.700000e+07   13084.500000    14.827784  2.685837e+07   105.000000
# 75%    4.200000e+07   46831.250000    30.258282  1.022818e+08   118.500000
# max    3.800000e+08  417859.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4392.000000   4392.000000
# mean       6.226935    754.441712
# std        0.893215   1272.263761
# min        1.900000     10.000000
# 25%        5.700000     83.750000
# 50%        6.300000    288.500000
# 75%        6.800000    831.000000
# ...

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_average, norm_hist = False, kde = False)
ax.set(xlabel='Nota Média', ylabel = 'Frequência')
ax.set_title("Média de votos em filmes no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/141386833.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_average, norm_hist = False, kde = False)
# Text(0.5, 1.0, 'Média de votos em filmes no TMDB 5000')

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_average)
ax.set(xlabel='Nota Média', ylabel = 'Densidade')
ax.set_title("Média de votos em filmes no TMDB 5000 dentre os filmes com mais de 10 votos")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/3122623318.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_average)
# Text(0.5, 1.0, 'Média de votos em filmes no TMDB 5000 dentre os filmes com mais de 10 votos')

# %%
ax = sns.boxplot(x=tmdb_com_mais_de_10_votos.vote_average)
ax.set(xlabel='Nota média do filme')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000 dentre os filmes com mais de 10 votos')
# Out:
# Text(0.5, 1.0, 'Distribuição de nota média dos filmes do TMDB 5000 dentre os filmes com mais de 10 votos')

# %% [markdown]
# # Analisaremos também o movielens

# %%
notas = pd.read_csv('dados/ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
nota_media_por_filme = notas.groupby('movieId').mean().rating
nota_media_por_filme.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.distplot(nota_media_por_filme.values)
ax.set(xlabel='Nota Média', ylabel = 'Densidade')
ax.set_title("Média de votos em filmes no Movielens 100k")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/2077832304.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme.values)
# Text(0.5, 1.0, 'Média de votos em filmes no Movielens 100k')

# %%
quantidade_de_votos_por_filme = notas.groupby('movieId').count()
filmes_com_pelo_menos_10_votos = quantidade_de_votos_por_filme.query("rating >= 10").index
filmes_com_pelo_menos_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593])

# %%
nota_media_por_filme_com_pelo_menos_10_votos = nota_media_por_filme.loc[filmes_com_pelo_menos_10_votos]

# %%
ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values)
ax.set(xlabel='Nota Média', ylabel = 'Densidade')
ax.set_title("Média de votos em filmes com pelo menos 10 votos no Movielens 100k")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/3249367042.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values)
# Text(0.5, 1.0, 'Média de votos em filmes com pelo menos 10 votos no Movielens 100k')

# %%
ax = sns.boxplot(x=nota_media_por_filme_com_pelo_menos_10_votos.values)
ax.set(xlabel='Nota média do filme')
ax.set_title('Distribuição de nota média dos filmes do Movilens 100k dentre os filmes com mais de 10 votos')
# Out:
# Text(0.5, 1.0, 'Distribuição de nota média dos filmes do Movilens 100k dentre os filmes com mais de 10 votos')

# %%
ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values, hist_kws = {'cumulative': True}, kde_kws = {'cumulative': True})
ax.set(xlabel='Nota Média', ylabel = '% acumulada de filmes')
ax.set_title("Média de votos em filmes com pelo menos 10 votos no Movielens 100k")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/2781908967.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(nota_media_por_filme_com_pelo_menos_10_votos.values, hist_kws = {'cumulative': True}, kde_kws = {'cumulative': True})
# Text(0.5, 1.0, 'Média de votos em filmes com pelo menos 10 votos no Movielens 100k')

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_average, 
                  hist_kws = {'cumulative': True}, 
                  kde_kws = {'cumulative': True})
ax.set(xlabel='Nota Média', ylabel = '% acumulada de filmes')
ax.set_title("Média de votos em filmes no TMDB 5000 dentre os filmes com mais de 10 votos")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/2733965222.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_average,
# Text(0.5, 1.0, 'Média de votos em filmes no TMDB 5000 dentre os filmes com mais de 10 votos')

# %% [markdown]
# # Análisando a distribuição dos dados capturados de outros campos do TMDB

# %%
ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_count)
ax.set(xlabel='Número de votos', ylabel = 'Densidade')
ax.set_title("Número de votos em filmes com pelo menos 10 votos no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/461435743.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb_com_mais_de_10_votos.vote_count)
# Text(0.5, 1.0, 'Número de votos em filmes com pelo menos 10 votos no TMDB 5000')

# %%
ax = sns.distplot(tmdb.query('budget > 0').budget)
ax.set(xlabel='Orçamento', ylabel = 'Densidade')
ax.set_title("Orçamento em filmes no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/4100415452.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('budget > 0').budget)
# Text(0.5, 1.0, 'Orçamento em filmes no TMDB 5000')

# %%
ax = sns.distplot(tmdb.popularity)
ax.set(xlabel='Popularidade', ylabel = 'Densidade')
ax.set_title("Popularidade em filmes no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/281753172.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.popularity)
# Text(0.5, 1.0, 'Popularidade em filmes no TMDB 5000')

# %%
ax = sns.distplot(tmdb.query('runtime > 0').runtime.dropna(),
                 hist_kws={'cumulative':True},
                 kde_kws={'cumulative':True},)
ax.set(xlabel='Tempo de duração do filme', ylabel = '% de Filmes')
ax.set_title("Tempo de duração dos filmes no TMDB 5000")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/139702508.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(tmdb.query('runtime > 0').runtime.dropna(),
# Text(0.5, 1.0, 'Tempo de duração dos filmes no TMDB 5000')

# %%
tmdb.query('runtime > 0').runtime.dropna().quantile(0.8)
# Out:
# 121.0

# %% [markdown]
# # Movielens: Média dos filmes com pelo menos 10 votos

# %%
print('Média dos filmes com pelo menos 10 votos', nota_media_por_filme_com_pelo_menos_10_votos.mean())
# Out:
# Média dos filmes com pelo menos 10 votos 3.4320503405352594

# %%
import matplotlib.pyplot as plt
import numpy as np

np.random.seed(75243)
temp = nota_media_por_filme_com_pelo_menos_10_votos.sample(frac=1)

medias = list()
medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint

zconfint(nota_media_por_filme_com_pelo_menos_10_votos)
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW

descr_todos_com_10_votos = DescrStatsW(nota_media_por_filme_com_pelo_menos_10_votos)
descr_todos_com_10_votos.tconfint_mean()
# Out:
# (3.41123483922938, 3.4528658418411386)

# %% [markdown]
# # Vamos ver o filme 1 ...

# %%
filmes = pd.read_csv('dados/movies.csv')
filmes.query('movieId==1')
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query('movieId == 1')
notas1.head()
# Out:
#       userId  movieId  rating   timestamp
# 0          1        1     4.0   964982703
# 516        5        1     4.0   847434962
# 874        7        1     4.5  1106635946
# 1434      15        1     2.5  1510577970
# 1667      17        1     4.5  1305696483

# %%
ax = sns.distplot(notas1.rating)
ax.set(xlabel='Nota', ylabel = 'Densidade')
ax.set_title("Distribuição de notas para o Toy Story")
# Out:
# /var/folders/y8/w682_7p55pxcxth1f7th6c5r0000gn/T/ipykernel_2513/2177995584.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(notas1.rating)
# Text(0.5, 1.0, 'Distribuição de notas para o Toy Story')

# %%
ax = sns.boxplot(x=notas1.rating)
ax.set(xlabel='Nota')
ax.set_title('Distribuição de notas para o Toy Story')
# Out:
# Text(0.5, 1.0, 'Distribuição de notas para o Toy Story')

# %%
notas1.rating.mean()
# Out:
# 3.9209302325581397

# %%
notas1.rating.count()
# Out:
# 215

# %%
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
from statsmodels.stats.weightstats import ztest

ztest(notas1.rating, value = 3.433)
# Out:
# (8.569663155533648, 1.0378817766831197e-17)

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

medias = [temp[0:i].mean() for i in range(1, len(temp))]

plt.plot(medias)

# %%
np.random.seed(75241)
temp = notas1.sample(frac=1).rating

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value = 3.4320503405352603) 
    return (i, media, p)

valores = np.array([calcula_teste(i) for i in range(2, len(temp))])

plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2])
plt.hlines(y = 0.05, xmin = 2, xmax = len(temp), colors = 'red')

# %% [markdown]
# # Comparação de 2 conjuntos de amostras

# %%
print(ztest(notas1.rating, notas.rating))
zconfint(notas1.rating, notas.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)
# (0.2799245129192442, 0.5588219849631111)

# %%
print(ztest(notas.rating, notas1.rating))
zconfint(notas.rating, notas1.rating)
# Out:
# (-5.894327101501841, 3.762112778881965e-09)
# (-0.5588219849631111, -0.2799245129192442)

# %%
from scipy.stats import ttest_ind

ttest_ind(notas.rating, notas1.rating)
# Out:
# TtestResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09, df=101049.0)

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)

comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
plt.boxplot([notas1.rating, notas.rating], labels = ['ToyStory','Todas as notas'])
plt.title('Distribuição das notas com todos os filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas com todos os filmes')

# %%
plt.boxplot([notas1.rating[3:12], notas.rating], labels = ['ToyStory do 3 ao 12','Todas as notas'])
plt.title('Distribuição das notas com todos os filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas com todos os filmes')

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1[3:12].rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)

comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# # Comparar a média de dois filmes

# %%
filmes.query('movieId in [1, 593, 72226]')
# Out:
#       movieId                             title  \
# 0           1                  Toy Story (1995)
# 510       593  Silence of the Lambs, The (1991)
# 7180    72226          Fantastic Mr. Fox (2009)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 510                         Crime|Horror|Thriller
# 7180    Adventure|Animation|Children|Comedy|Crime

# %%
notas1 = notas.query('movieId == 1')
notas593 = notas.query('movieId == 593')
notas72226 = notas.query('movieId == 72226')

# %%
plt.boxplot([notas1.rating, 
             notas593.rating, 
             notas72226.rating], labels = ['ToyStory','Silencio dos inocentes', 'Fantastico senhor raposta'])
plt.title('Distribuição das notas com todos os filmes')
# Out:
# Text(0.5, 1.0, 'Distribuição das notas com todos os filmes')

# %%
notas72226.describe()
# Out:
#            userId  movieId     rating     timestamp
# count   18.000000     18.0  18.000000  1.800000e+01
# mean   329.722222  72226.0   4.083333  1.395218e+09
# std    174.748157      0.0   0.895249  9.459862e+07
# min     73.000000  72226.0   1.500000  1.262899e+09
# 25%    167.000000  72226.0   4.000000  1.279706e+09
# 50%    326.000000  72226.0   4.250000  1.441777e+09
# 75%    466.250000  72226.0   4.500000  1.471770e+09
# max    610.000000  72226.0   5.000000  1.498522e+09

# %%
sns.boxplot(x = 'movieId', y = 'rating', data = notas.query('movieId in (1, 593, 72226)'))
# Out:
# <Axes: xlabel='movieId', ylabel='rating'>

# %%
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.query('movieId in (1, 593, 72226)').groupby('movieId').count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %%
descr_1 = DescrStatsW(notas1.rating)
descr_593 = DescrStatsW(notas593.rating)
descr_72226 = DescrStatsW(notas72226.rating)
comparacao = descr_72226.get_compare(descr_593)

comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_1.get_compare(descr_72226)

comparacao.summary(use_t = True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
from scipy.stats import normaltest

_, p_value = normaltest(notas1.rating)
print(p_value)
# Out:
# 0.00011053430732728716

# %%
from scipy.stats import ranksums

_, p = ranksums(notas1.rating, notas593.rating)
print(p)
# Out:
# 0.0003267718756440693
